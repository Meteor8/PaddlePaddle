# %% [markdown]
# # 口罩测试

# %%
import paddle
import paddlehub as hub
import cv2

import matplotlib.pyplot as plt 
import matplotlib.image as mpimg 

# %matplotlib inline

# %% [markdown]
# ## 加载待检测图片

# %%
test_img_path = "data/mask/zhoujielun.jpg"
img = mpimg.imread(test_img_path)
plt.figure(figsize=(10,10))
plt.imshow(img) 
plt.axis('off') 
plt.show()

# %% [markdown]
# ## 检测

# %%
module = hub.Module(name="pyramidbox_lite_mobile_mask")
input_dict = {"data": [cv2.imread(test_img_path)]}
results = module.face_detection(data=input_dict)
print(results)
# Out:
# [2020-12-04 18:39:45,722] [    INFO] - Installing pyramidbox_lite_mobile_mask module
# [2020-12-04 18:39:46,133] [    INFO] - Module pyramidbox_lite_mobile_mask already installed in C:\Users\dong\.paddlehub\modules\pyramidbox_lite_mobile_mask
# [2020-12-04 18:39:46,136] [    INFO] - Installing pyramidbox_lite_mobile module
# [2020-12-04 18:39:46,146] [    INFO] - Module pyramidbox_lite_mobile already installed in C:\Users\dong\.paddlehub\modules\pyramidbox_lite_mobile
# [{'data': [{'label': 'NO MASK', 'confidence': 0.9997952580451965, 'top': 38, 'bottom': 127, 'left': 252, 'right': 325}], 'path': 'ndarray_time=1607078386436581.0'}]
